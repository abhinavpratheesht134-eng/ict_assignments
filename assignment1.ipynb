# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavpratheesht134-eng/ict_assignments/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item1_price = float(input("Item1 price: "))
item1_quantity = int(input("Item1 quantity: "))

item2_price = float(input("Item2 price: "))
item2_quantity = int(input("Item2 quantity: "))

total_bill = (item1_price * item1_quantity) + (item2_price * item2_quantity)

print(f"Total Bill: {total_bill}")
# Out:
# Item1 price: 45
# Item1 quantity: 3
# Item2 price: 30
# Item2 quantity: 2
# Total Bill: 195.0

# %%
celsius = float(input('Enter temperature in celsius:'))
fahenheit = (celsius * 9/5) + 32
print('Temperature in fahenheit:', fahenheit)
# Out:
# Enter temperature in celsius:30
# Temperature in fahenheit: 86.0

# %%
salary = int(input('Enter the salary:'))
total = salary*0.2 + salary*0.1+salary
print('Total salary:', total)
# Out:
# Enter the salary:20000
# Total salary: 26000.0

# %%
P=int(input( 'Enter principal:'))
R=int(input('Enter rate:'))
T=int(input('Enter time'))
si=(P*R*T)/100
print('Simple interest:',si)
# Out:
# Enter principal:10000
# Enter rate:5
# Enter time2
# Simple interest: 1000.0

# %%
m = int(input('Enter the minutes: '))
h=m//60
m=m%60
print(h,'hours'' and',m,'minutes')
# Out:
# Enter the minutes: 130
# 2 hours and 10 minutes

# %%
w = float(input('Enter the weight in kg:'))
h = float(input('Enter the height in m:'))
BMI = w/(h*h)
print('BMI =',BMI)
# Out:
# Enter the weight in kg:60
# Enter the height in m:1.65
# BMI = 22.03856749311295

# %%
a=int(input("enter wall lenght(in m):"))
b=int(input("enter wall height(in m):"))
window_area=1.5*1.2
wall_area=a*b
paint_area=wall_area-window_area
cost = paint_area*25
print("Total area to be painted:",paint_area)
print("total cost",cost)
# Out:
# enter wall lenght(in m):12
# enter wall height(in m):8
# Total area to be painted: 94.2
# total cost 2355.0

# %%
a=float(input("enter no of unit consumed:"))
f=100
rate=a*5.2
total_bill=rate+100
print("electricity bill:" ,total_bill)
# Out:
# enter no of unit consumed:250
# electricity bill: 1400.0

# %%
p = float(input('Enter the original price'))
d = 0.10*p
x = p-d
print('Discounted price:',x)
# Out:
# Enter the original price1200
# Discounted price: 1080.0

# %%
import math
a = int(input('Enter side a:'))
b = int(input('Enter side b:'))
c = int(input('Enter side c:'))
s = (a+b+c)/2
area = math.sqrt(s*(s-a)*(s-b)*(s-c))
print('area of triangle:',area)
# Out:
# Enter side a:5
# Enter side b:6
# Enter side c:7
# area of triangle: 14.696938456699069
